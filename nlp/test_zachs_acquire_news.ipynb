# %%
import os
import json
import itertools as it
from typing import List, Dict

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
BASE_URL = 'https://inshorts.com/en/read'
SECTIONS = ['business', 'sports', 'technology', 'entertainment']

def handle_article(article: BeautifulSoup) -> Dict[str, str]:
    '''
    Given a single article, extracts the title and content
    '''
    return {
        'title': article.find(class_ = 'news-card-title').find('a').text.strip(),
        'content': (article.find(class_='news-card-content')
                    .find('div', attrs={'itemprop': 'articleBody'})
                    .text.strip())
        }

# %%
def fetch_section(section: str) -> List[Dict[str, str]]:
    '''
    Make a request for the given section and processes all the articles in it
    '''
    url = f'{BASE_URL}/{section}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    articles = [handle_article(article) for article in soup.find_all(class_='news-card')]
    for article in articles:
        article['category'] = section
    return articles

# %%
def get_all_sections() -> List[Dict[str, str]]:
    '''
    Returns the processed article data for all of the sections we defined in
    '''
    sections = [fetch_section(section) for section in SECTIONS]
    # flatten out the nested lists with it.chain
    return list(it.chain(*sections))

# %%
def get_news_articles(use_cache=True) -> List[Dict[str, str]]:
    if use_cache and os.path.exists('news_articles.json'):
        articles = json.load(open('news_articles.json'))
    else:
        articles = get_all_sections()
        json.dump(articles, open('news_articles.json', 'w'))
    return articles

# %%
def get_news_data() -> pd.DataFrame:
    '''
    Returns all the articles from all the sections as a pandas DataFrame
    '''
    return pd.DataFrame(get_all_sections())

# %%
get_news_data()
# Out:
#          category                                            content  \
# 0        business  Ratan Tata, the Chairman Emeritus of Tata Sons...
# 1        business  On being asked how Congress will fund its NYAY...
# 2        business  After Rahul Gandhi called Anil Ambani a crony ...
# 3        business  The Reliance Group has accused Rahul Gandhi of...
# 4        business  After world's fourth-richest person Warren Buf...
# 5        business  The Supreme Court on Monday stayed the ₹500-cr...
# 6        business  World's fourth-richest person, Warren Buffett,...
# 7        business  Yes Bank has slipped three spots to 10th spot ...
# 8        business  India's largest oil producer ONGC's cash reser...
# 9        business  The British police has said the leak of inform...
# 10       business  Berkshire Hathaway CEO Warren Buffett, while t...
# 11       business  China's Xiaomi has released a statement disput...
# 12       business  E-commerce conglomerate Infibeam Avenues' boar...
# 13       business  PepsiCo India withdrew its lawsuit against two...
# 14       business  Iran's Deputy Oil Minister has said the countr...
# 15       business  Pakistan on Sunday named International Monetar...
# 16       business  India has warned the World Trade Organisation ...
# 17       business  Private lender ICICI Bank on Monday posted a p...
# 18       business  American IT giant Cognizant announced it is co...
# 19       business  Infrastructure major Larsen & Toubro (L&T) on ...
# 20       business  The government sees little hope of a bidder em...
# 21       business  India's largest drugmaker Sun Pharma is lookin...
# 22       business  Boeing on Sunday revealed some of its 737 MAX ...
# 9   No crime in Huawei leak: UK police after defen...
# 10  Bitcoin is like a seashell, not an investment:...
# 11  Inaccurate, unfair: Xiaomi on reported Q1 phon...
# 12  Infibeam terminates EY affiliated auditor citi...
# 13  PepsiCo India withdraws lawsuit against two Gu...
# 14  Using all means to sell oil in grey market: Ir...
# 15  IMF official replaces fired Pak central bank G...
# 16  India warns WTO about EU's proposal for new e-...
# 17  ICICI Bank profit falls 5% to ₹969 crore in Ma...
# 18  Cognizant may cut jobs as it slashes growth fo...
# 19  L&T buys Mindtree shares worth ₹113 crore via ...
# 20  Govt has little hope of finding buyer for Jet ...
# 21  China is a big opportunity for Sun Pharma: Fou...
# 22  Boeing admits some 737 MAX planes had safety a...
# 23  Bharti Airtel profit rises 30% to ₹107 cr in f...
# 24  Ex-bosses at French telco on trial over worker...
# 25  Fan asks Unadkat to join academy to learn how ...
# 26  Bhogle clarifies after mistakenly snubbing Har...
# 27   What are the matchups for the IPL 2019 playoffs?
# 28  MS Dhoni votes in Ranchi, shares video of Ziva...
# 29  Rayudu, Shankar end IPL 2019 league stage with...
# ..                                                ...
# 69  IBM-backed project makes WiFi network for natu...
# 70  Facebook's 8-year-serving execs made heads of ...
# 71  Bitcoin is like a seashell, not an investment:...
# 72  Inaccurate, unfair: Xiaomi on reported Q1 phon...
# 73  Facebook to shut down group video chat test ap...
# 74  Want to be known for who I am, not just as Mah...
# 75  Teachers threaten misbehaving students with 'E...
# 76  Fans claim spotting Starbucks cup in GoT episo...
# 77  Giving my kids phones nearly ended our relatio...
# 78  Fan chases Vaani Kapoor on bike in Mumbai, act...
# 79  Sanya to star in Monga's film whose documentar...
# 80  42-yr-old Australian DJ dies in Bali while hel...
# 81  Know real from reel: Abhay shares his photosho...
# 82  Will tell kids how I met their father: Priyank...
# 83  Ranbir has a secret account, showed me how Ins...
# 84  Kylie saved up, built her own business : Kris ...
# 85  As a mother, I had to be strong: Soni on Shahe...
# 86  Stop it, you don't need to explain: Kher to Ak...
# 87  Apologise or we'll beat you: Karni Sena to Akh...
# 88  Siddharth said he isn't ready: Madhu on son's ...
# 89  Owner said I couldn't handle it: Katrina on dr...
# 90  People are mean, obnoxious: Actress on man cal...
# 91  Jackie Shroff once borrowed ₹5 from me to give...
# 92  'Avengers: Endgame' 1st Hollywood film to earn...
# 93  Akshay's eligibility for National Award questi...
# 94  Karan Oberoi filmed female astrologer during r...
# 95  Endgame fastest movie to gross $2 billion, ach...
# 96  Haven't yet made name for myself in Bollywood:...
# 97  Vivek Oberoi urges Delhi people to vote for PM...
# 98  Sadak 2 isn't new beginning for me as director...
#
# [99 rows x 3 columns]
